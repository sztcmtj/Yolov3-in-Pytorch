# %%
from torchvision import datasets

from pathlib import Path

from PIL import Image,ImageDraw

root = Path('/home/f/learning/Dataset/coco2014/train2014/')

anno = Path('/home/f/learning/Dataset/coco2014/annotations/instances_train2014.json')

dataset = datasets.CocoDetection(root,anno)
# Out:
# loading annotations into memory...
# Done (t=9.95s)
# creating index...
# index created!

# %%
from pycocotools.coco import COCO

# %%
a = dataset[0]

# %%
a[0]
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F6B75368DD8>

# %%
img = a[0]

# %%
draw = ImageDraw.Draw(img)

# %%
a[1][4]['bbox']
# Out:
# [367.82, 264.27, 139.15, 215.73]

# %%
i=1

# %%
draw.rectangle((int(a[1][i]['bbox'][0]),int(a[1][i]['bbox'][1]),int(a[1][i]['bbox'][0]+a[1][i]['bbox'][2]),int(a[1][i]['bbox'][1]+a[1][i]['bbox'][3])),outline = "red")

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F6B75368DD8>

# %%
a[1][4]
# Out:
# {'area': 15494.157900000004,
#  'bbox': [367.82, 264.27, 139.15, 215.73],
#  'category_id': 62,
#  'id': 290682,
#  'image_id': 57870,
#  'iscrowd': 0,
#  'segmentation': [[381.84,
#    382.92,
#    390.47,
#    365.66,
#    396.94,
#    358.11,
#    412.04,
#    358.11,
#    419.6,
#    350.56,
#    426.07,
#    299.87,
#    435.78,
#    279.37,
#    467.06,
#    265.35,
#    487.55,
#    264.27,
#    506.97,
#    284.76,
#    506.97,
#    319.28,
#    486.47,
#    353.8,
#    475.69,
#    378.61,
#    477.84,
#    409.89,
#    490.79,
#    480.0,
#    483.24,
#    475.69,
#    475.69,
#    449.8,
#    469.21,
#    439.01,
#    453.03,
#    437.93,
#    443.33,
#    437.93,
#    437.93,
#    441.17,
#    433.62,
#    453.03,
#    430.38,
#    472.45,
#    432.54,
#    480.0,
#    426.07,
#    480.0,
#    421.75,
#    469.21,
#    419.6,
#    456.27,
#    417.44,
#    448.72,
#    416.36,
#    443.33,
#    415.28,
#    437.93,
#    380.76,
#    434.7,
#    376.45,
#    432.54,
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
import numpy as np
import skimage.io as io
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
annType = ['segm','bbox','keypoints']
annType = annType[1]      #specify type here
prefix = 'person_keypoints' if annType=='keypoints' else 'instances'
print('Running demo for *%s* results.'%(annType))
# Out:
# Running demo for *bbox* results.

# %%
import os
os.chdir('/home/f/learning/Dataset/coco2014')

# %%
#initialize COCO ground truth api
dataDir='./'
dataType='val2014'
annFile = '%s/annotations/%s_%s.json'%(dataDir,prefix,dataType)
cocoGt=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=13.46s)
# creating index...
# index created!

# %%
#initialize COCO detections api
resFile='%s/results/%s_%s_fake%s100_results.json'
resFile = resFile%(dataDir, prefix, dataType, annType)
cocoDt=cocoGt.loadRes(resFile)
# Out:
# Loading and preparing results...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-897692a3333a> in <module>()
#       2 resFile='%s/results/%s_%s_fake%s100_results.json'
#       3 resFile = resFile%(dataDir, prefix, dataType, annType)
# ----> 4 cocoDt=cocoGt.loadRes(resFile)
#
# ~/anaconda3/lib/python3.6/site-packages/pycocotools/coco.py in loadRes(self, resFile)
#     307         tic = time.time()
#     308         if type(resFile) == str or type(resFile) == unicode:
# --> 309             anns = json.load(open(resFile))
#     310         elif type(resFile) == np.ndarray:
#     311             anns = self.loadNumpyAnnotations(resFile)
#
# FileNotFoundError: [Errno 2] No such file or directory: './/results/instances_val2014_fakebbox100_results.json'

# %%
from pycocotools.cocoeval import COCOeval

# %%
cats = coco.loadCats(coco.getCatIds())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8e127656636e> in <module>()
# ----> 1 cats = coco.loadCats(coco.getCatIds())
#
# NameError: name 'coco' is not defined

# %%
nms = [cat[‘name‘] for cat in cats]
print(‘COCO categories: \n{}\n‘.format(‘ ‘.join(nms)))

nms = set([cat[‘supercategory‘] for cat in cats])
print(‘COCO supercategories: \n{}‘.format(‘ ‘.join(nms)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-8904628cffb8> in <module>()
# ----> 1 cocoGt.dataset[10]
#
# KeyError: 10
